# %%
# %run BlowupGraph2.ipynb
# %run LocalColoring.ipynb
# %run DrawGradedComplex1.ipynb

# %%
netspec = 'X : ~Y X \n Y: ~X Y'
network = DSGRN.Network(netspec)
DSGRN.DrawGraph(network)

# %%
net_spec =netspec
network = DSGRN.Network(net_spec)
parameter_graph = DSGRN.ParameterGraph(network)

#params = range(0,g.size())

par_index=126
    
parameter = parameter_graph.parameter(par_index)

std = BlowupGraph2(parameter,2)
(dag, fibration)= FlowGradedComplex(std.complex(), std.diagram())
connection_matrix = ConnectionMatrix(fibration)
conleyindices = connection_matrix.count()
fringenode = fibration.value(std.complex().size()-1)
del conleyindices[fringenode]
CMG = InducedPoset(dag, lambda v : v in conleyindices)



DrawGradedComplex1(connection_matrix, CMG, LocalColoring(CMG), list(CMG.vertices()))    
#ComputeDatabase(netspec, params)

# %%
LocalColoring(CMG,12)
# Out:
# [{0, 1, 2}, {6}, set()]

# %%
std.cc.cell_shape(25)
# Out:
# 1

# %%
std.cc.coordinates(25)
# Out:
# [1, 2]

# %%
std.cc.cell_shape(57)
# Out:
# 3

# %%
std.cc.coordinates(57)
# Out:
# [1, 2]

# %%
std.cc.shape_begin(25)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-ee4cace3e082> in <module>
# ----> 1 std.cc.shape_begin(25)
#
# AttributeError: 'pychomp._chomp.CubicalComplex' object has no attribute 'shape_begin'

# %%
std.labelling
# Out:
# [0, 4, 0, 2, 3, 3, 0, 1, 3]

# %%
std.labelling[34]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-d5dc1bba69ae> in <module>
# ----> 1 std.labelling[34]
#
# IndexError: list index out of range
