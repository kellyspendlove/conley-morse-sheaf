# %%
import DSGRN
from pychomp import *
from TransversalitySheaf import *
from ConleySheaf import *
from FlowSheaf import *
from CubicalSheaf import *

# %%
def dsgrn(pg, pi, method = "blowup"):
    p = pg.parameter(pi)
    if method == "original":
        dg = DSGRN.DomainGraph(p)
        md = DSGRN.MorseDecomposition(dg.digraph())
        mg = DSGRN.MorseGraph(dg, md)
        return DSGRN.DrawGraph(mg)  
    if method == "cubical":
        std = DSGRN.SubdomainGraph(p)
    elif method == "blowup":
        std = DSGRN.BlowupGraph(p)
    (dag, graded_complex)= FlowGradedComplex(std.complex(), std.diagram())
    connection_matrix = ConnectionMatrix(graded_complex)
    conleyindices = connection_matrix.count()
    fringenode = graded_complex.value(std.complex().size()-1)
    #del conleyindices[fringenode]
    CMG = InducedPoset(dag, lambda v : v in conleyindices)
    return DrawGradedComplex(connection_matrix, CMG)

# %%
def ComputeDatabase(netspec, params = None):
    network = DSGRN.Network(netspec)
    pg = DSGRN.ParameterGraph(network)
    if not params:
        params = range(0,pg.size())
    return DSGRN.Table( ['ParameterIndex','Original', 'Cubical', 'Blowup'], 
                   [[pi,
                     dsgrn(pg, pi, "original"), 
                     dsgrn(pg, pi, "cubical"), 
                     dsgrn(pg, pi, "blowup")] for pi in params])

# %%
ComputeDatabase("X : ~Y\n Y : ~X\n")
# Out:
# <div style="border:1px black"><table><tr><th><div style="text-align:center;">ParameterIndex</div></th><th><div style="text-align:center;">Original</div></th><th><div style="text-align:center;">Cubical</div></th><th><div style="text-align:center;">Blowup</div></th></tr><tr><td><div style="text-align:center;">0</div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="104pt" height="44pt"
#  viewBox="0.00 0.00 104.01 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 100.0135,-40 100.0135,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="48.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="48.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">FP { 0, 0 }</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="116pt"
#  viewBox="0.00 0.00 106.81 116.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-112 102.8117,-112 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-90" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-85.8" font-family="Times,serif" font-size="14.00" fill="#000000">7 : (0, 2, 1)</text>
# </g>
# <!-- 1&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>1&#45;&gt;0</title>
# <path fill="none" stroke="#000000" d="M49.4058,-71.8314C49.4058,-64.131 49.4058,-54.9743 49.4058,-46.4166"/>
# <polygon fill="#000000" stroke="#000000" points="52.9059,-46.4132 49.4058,-36.4133 45.9059,-46.4133 52.9059,-46.4132"/>
# </g>
# </g>
# </svg>
# </div></td></tr><tr><td><div style="text-align:center;">1</div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="104pt" height="44pt"
#  viewBox="0.00 0.00 104.01 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 100.0135,-40 100.0135,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="48.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="48.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">FP { 1, 0 }</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="44pt"
#  viewBox="0.00 0.00 106.81 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 102.8117,-40 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# </g>
# </svg>
# </div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="107pt" height="116pt"
#  viewBox="0.00 0.00 106.81 116.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 112)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-112 102.8117,-112 102.8117,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-18" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000">0 : (1, 0, 0)</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="#00ffff" stroke="#000000" cx="49.4058" cy="-90" rx="49.3119" ry="18"/>
# <text text-anchor="middle" x="49.4058" y="-85.8" font-family="Times,serif" font-size="14.00" fill="#000000">5 : (0, 2, 1)</text>
# </g>
# <!-- 1&#45;&gt;0 -->
# <g id="edge1" class="edge">
# <title>1&#45;&gt;0</title>
# <path fill="none" stroke="#000000" d="M49.4058,-71.8314C49.4058,-64.131 49.4058,-54.9743 49.4058,-46.4166"/>
# <polygon fill="#000000" stroke="#000000" points="52.9059,-46.4132 49.4058,-36.4133 45.9059,-46.4133 52.9059,-46.4132"/>
# </g>
# </g>
# </svg>
# </div></td></tr><tr><td><div style="text-align:center;">2</div></td><td><div style="text-align:center;"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="104pt" height="44pt"
#  viewBox="0.00 0.00 104.01 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-40 100.0135,-40 100.0135,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="48.0068" cy="-18" rx="48.0135" ry="18"/>
# <text text-anchor="middle" x="48.0068" y="-13.8" font-family="Times,serif" font-size="14.00" fill="#000000

# %%
#Specs
netspec = "X : ~Y\n Y : ~X\n"
network = DSGRN.Network(netspec)
pg = DSGRN.ParameterGraph(network)

# %%
C,flow_map = dsgrnComplex(pg,0)
for top_cell in C(C.dimension()):
    print(top_cell,type(flow_map(top_cell)))
# Out:
# 180 <class 'set'>
# 181 <class 'set'>
# 182 <class 'set'>
# 183 <class 'set'>
# 184 <class 'set'>
# 185 <class 'set'>
# 186 <class 'set'>
# 187 <class 'set'>
# 188 <class 'set'>
# 189 <class 'set'>
# 190 <class 'set'>
# 191 <class 'set'>
# 192 <class 'set'>
# 193 <class 'set'>
# 194 <class 'set'>
# 195 <class 'set'>
# 196 <class 'set'>
# 197 <class 'set'>
# 198 <class 'set'>
# 199 <class 'set'>
# 200 <class 'set'>
# 201 <class 'set'>
# 202 <class 'set'>
# 203 <class 'set'>
# 204 <class 'set'>
# 205 <class 'set'>
# 206 <class 'set'>
# 207 <class 'set'>
# 208 <class 'set'>
# 209 <class 'set'>
# 210 <class 'set'>
# 211 <class 'set'>
# 212 <class 'set'>
# 213 <class 'set'>
# 214 <class 'set'>
# 215 <class 'set'>

# %%
discrete_flow = {top_cell: flow_map(top_cell) for top_cell in C(C.dimension())}

# %%
discrete_flow
# Out:
# {180: {189, 197, 198, 204, 207, 212, 213, 215},
#  181: {189, 190, 199, 205, 207, 208, 213, 214},
#  182: {190, 191, 200, 206, 208, 209, 214, 215},
#  183: {191, 192, 198, 201, 207, 209, 210, 215},
#  184: {193, 202, 211},
#  185: {203, 211},
#  186: {194, 195, 201, 204, 209, 210, 212, 213},
#  187: {196, 211},
#  188: set(),
#  189: {180, 181, 207, 213},
#  190: {181, 182, 208, 214},
#  191: {182, 183, 209, 215},
#  192: {183, 184, 207, 210},
#  193: {185, 211},
#  194: {185, 186, 209, 212},
#  195: {186, 187, 210, 213},
#  196: {188},
#  197: {180, 188, 212, 215},
#  198: {180, 183, 207, 215},
#  199: {181, 184, 207, 208},
#  200: {182, 185, 208, 209},
#  201: {183, 186, 209, 210},
#  202: {187, 211},
#  203: {188},
#  204: {180, 186, 212, 213},
#  205: {181, 187, 213, 214},
#  206: {182, 188, 214, 215},
#  207: {180, 181, 183, 184, 189, 192, 198, 199},
#  208: {181, 182, 184, 185, 190, 193, 199, 200},
#  209: {182, 183, 185, 186, 191, 194, 200, 201},
#  210: {183, 184, 186, 187, 192, 195, 201, 202},
#  211: {185, 187, 188, 196, 203},
#  212: {180, 185, 186, 188, 194, 197, 203, 204},
#  213: {180, 181, 186, 187, 189, 195, 204, 205},
#  214: {181, 182, 187, 188, 190, 196, 205, 206},
#  215: {180, 182, 183, 188, 191, 197, 198, 206}}

# %%
def dsgrnComplex(pg, pi, method = "blowup"):
    p = pg.parameter(pi)
    if method == "original":
        dg = DSGRN.DomainGraph(p)
        md = DSGRN.MorseDecomposition(dg.digraph())
        mg = DSGRN.MorseGraph(dg, md)
        return DSGRN.DrawGraph(mg)  
    if method == "cubical":
        std = DSGRN.SubdomainGraph(p)
    elif method == "blowup":
        std = DSGRN.BlowupGraph(p)
    C,flow_map = std.complex(),std.diagram()
    discrete_flow = {top_cell: flow_map(top_cell) for top_cell in C(C.dimension())}
    return C,discrete_flow

# %%
base_complex = GeometricCubicalComplex([[0,2],[0,2]],[2,2])

# %%
#Construct sheaf mapping
mapping = {}
B = base_complex.complex
for pi in B(0):
    C,discrete_flow = dsgrnComplex(pg,pi)
    print(type(C),type(discrete_flow))
    mapping[pi] = FlowComplex(C,discrete_flow)
# Out:
# <class 'pychomp._chomp.DualComplex'> <class 'dict'>
# <class 'pychomp._chomp.DualComplex'> <class 'dict'>
# <class 'pychomp._chomp.DualComplex'> <class 'dict'>
# <class 'pychomp._chomp.DualComplex'> <class 'dict'>
# <class 'pychomp._chomp.DualComplex'> <class 'dict'>
# <class 'pychomp._chomp.DualComplex'> <class 'dict'>
# <class 'pychomp._chomp.DualComplex'> <class 'dict'>
# <class 'pychomp._chomp.DualComplex'> <class 'dict'>
# <class 'pychomp._chomp.DualComplex'> <class 'dict'>

# %%
vertex_flow_sheaf = CubicalSheaf(base_complex, mapping)

# %%
flow_sheaf = SheafFromVertices(vertex_flow_sheaf)

# %%
graded_sheaf = GradeFlowSheaf(flow_sheaf)

# %%
graded_sheaf

# %%
params = range(0,pg.size())
DSGRN.Table( ['ParameterIndex','Conley Complex'], 
                [[pi, graded_sheaf.mapping[pi]] for pi in B(0)])
# Out:
# <div style="border:1px black"><table><tr><th><div style="text-align:center;">ParameterIndex</div></th><th><div style="text-align:center;">Conley Complex</div></th></tr><tr><td><div style="text-align:center;">0</div></td><td><div style="text-align:center;"><pychomp.GradedComplex.GradedComplexObj object at 0x11afb0438></div></td></tr><tr><td><div style="text-align:center;">1</div></td><td><div style="text-align:center;"><pychomp.GradedComplex.GradedComplexObj object at 0x11aeb6ac8></div></td></tr><tr><td><div style="text-align:center;">2</div></td><td><div style="text-align:center;"><pychomp.GradedComplex.GradedComplexObj object at 0x11aeb6a90></div></td></tr><tr><td><div style="text-align:center;">3</div></td><td><div style="text-align:center;"><pychomp.GradedComplex.GradedComplexObj object at 0x11aeb6cc0></div></td></tr><tr><td><div style="text-align:center;">4</div></td><td><div style="text-align:center;"><pychomp.GradedComplex.GradedComplexObj object at 0x11b179438></div></td></tr><tr><td><div style="text-align:center;">5</div></td><td><div style="text-align:center;"><pychomp.GradedComplex.GradedComplexObj object at 0x11b179550></div></td></tr><tr><td><div style="text-align:center;">6</div></td><td><div style="text-align:center;"><pychomp.GradedComplex.GradedComplexObj object at 0x11b179668></div></td></tr><tr><td><div style="text-align:center;">7</div></td><td><div style="text-align:center;"><pychomp.GradedComplex.GradedComplexObj object at 0x11b179780></div></td></tr><tr><td><div style="text-align:center;">8</div></td><td><div style="text-align:center;"><pychomp.GradedComplex.GradedComplexObj object at 0x11b179898></div></td></tr></div></table></div>
